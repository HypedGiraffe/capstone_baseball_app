# %%
#!pip install pybaseball

# %%
from pybaseball import pitching_stats
import pandas as pd
import seaborn as sns
import numpy as np

# %%
seasonal_pitching = pitching_stats(1980,2020, ind=1)
career_pitching = pitching_stats(1980, 2020, qual=20, ind=0)

# %%
seasonal_pitching.head()
# Out:
#      IDfg  Season            Name Team  Age   W  L   WAR   ERA   G  ...  LA  \
# 22    200    1999  Pedro Martinez  BOS   27  23  4  11.6  2.07  31  ... NaN
# 21    815    1997   Roger Clemens  TOR   34  21  7  10.7  2.05  34  ... NaN
# 124    60    2001   Randy Johnson  ARI   37  21  6  10.4  2.49  35  ... NaN
# 175    60    2000   Randy Johnson  ARI   36  19  7   9.6  2.64  35  ... NaN
# 78    642    1998     Kevin Brown  SDP   33  18  7   9.6  2.38  36  ... NaN
#
#      Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%  CSW%  xERA
# 22       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 21       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 124      NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 175      NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
# 78       NaN      NaN    NaN      NaN       NaN       0    NaN   NaN   NaN
#
# [5 rows x 334 columns]

# %%
for col in seasonal_pitching:
    seasonal_pitching = seasonal_pitching.dropna(thresh=4000, axis=1)

# %%
pct_null = seasonal_pitching.isnull().sum() / len(seasonal_pitching)
missing_features = pct_null[pct_null > 0.80].index
seasonal_pitching.drop(missing_features, axis=1, inplace=True)

# %%
career_pitching.head()
# Out:
#      IDfg            Name   Team  Age    W    L   ERA    WAR    G   GS  ...  \
# 210   815   Roger Clemens  - - -   33  354  184  3.12  133.7  709  707  ...
# 233   104     Greg Maddux  - - -   31  355  227  3.16  116.7  744  740  ...
# 318    60   Randy Johnson  - - -   34  303  166  3.29  110.5  618  603  ...
# 120   200  Pedro Martinez  - - -   27  219  100  2.93   84.4  476  409  ...
# 692   837    Mike Mussina  - - -   31  270  153  3.68   81.2  537  536  ...
#
#      LA  Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# 210 NaN      0.0      NaN    NaN      0.0       NaN       0  0.166  0.277
# 233 NaN      0.0      NaN    NaN      0.0       NaN       0  0.190  0.269
# 318 NaN      0.0      NaN    NaN      0.0       NaN       0  0.175  0.303
# 120 NaN      0.0      NaN    NaN      0.0       NaN       0  0.185  0.305
# 692 NaN      0.0      NaN    NaN      0.0       NaN       0  0.201  0.281
#
#      xERA
# 210   NaN
# 233   NaN
# 318   NaN
# 120   NaN
# ...

# %%
x = career_pitching.columns
for i in range(0, len(x)):
    print(x[i])
# Out:
# IDfg
# Name
# Team
# Age
# W
# L
# ERA
# WAR
# G
# GS
# CG
# ShO
# SV
# BS
# IP
# TBF
# H
# R
# ER
# HR
# BB
# IBB
# HBP
# WP
# BK
# SO
# GB
# FB
# LD
# IFFB
# Balls
# Strikes
# Pitches
# RS
# IFH
# BU
# BUH
# K/9
# BB/9
# K/BB
# H/9
# HR/9
# AVG
# WHIP
# BABIP
# LOB%
# FIP
# GB/FB
# LD%
# GB%
# FB%
# IFFB%
# HR/FB
# IFH%
# BUH%
# Starting
# Start-IP
# Relieving
# Relief-IP
# RAR
# Dollars
# tERA
# xFIP
# WPA
# -WPA
# +WPA
# RE24
# REW
# pLI
# inLI
# gmLI
# exLI
# Pulls
# WPA/LI
# Clutch
# FB% 2
# FBv
# SL%
# SLv
# CT%
# CTv
# CB%
# CBv
# CH%
# CHv
# SF%
# SFv
# KN%
# KNv
# XX%
# PO%
# wFB
# wSL
# wCT
# wCB
# wCH
# wSF
# wKN
# wFB/C
# wSL/C
# wCT/C
# wCB/C
# wCH/C
# wSF/C
# wKN/C
# O-Swing%
# Z-Swing%
# Swing%
# O-Contact%
# Z-Contact%
# Contact%
# Zone%
# F-Strike%
# SwStr%
# HLD
# SD
# MD
# ERA-
# FIP-
# xFIP-
# K%
# BB%
# SIERA
# RS/9
# E-F
# FA% (sc)
# FT% (sc)
# FC% (sc)
# FS% (sc)
# FO% (sc)
# SI% (sc)
# SL% (sc)
# CU% (sc)
# KC% (sc)
# EP% (sc)
# CH% (sc)
# SC% (sc)
# ...

# %%
#Making Stat Specific Dataframes
df_career = pd.DataFrame()
df_career['id'] = career_pitching['IDfg']
df_career['g'] = career_pitching['G']
df_career['war'] = career_pitching['WAR']
df_career['era'] = career_pitching['ERA']
df_career['k/9'] = career_pitching['K/9']

# %%
df_career.corr()
# Out:
#            id         g       war       era       k/9
# id   1.000000 -0.076986 -0.031068 -0.006473 -0.481491
# g   -0.076986  1.000000  0.516386 -0.423136  0.161677
# war -0.031068  0.516386  1.000000 -0.296832  0.078824
# era -0.006473 -0.423136 -0.296832  1.000000 -0.180620
# k/9 -0.481491  0.161677  0.078824 -0.180620  1.000000
